# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/Dio_ETL_projeto/ocorrencia.csv", sep=";", parse_dates=['ocorrencia_dia'], dayfirst=True)
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2  ... ocorrencia_hora total_recomendacoes
# 0              40211               40211  ...        12:00:00                   0
# 1              40349               40349  ...        11:05:00                   0
# 2              40351               40351  ...        03:00:00                   0
# 3              39527               39527  ...        17:30:00                   0
# 4              40324               40324  ...        19:25:00                   0
#
# [5 rows x 9 columns]

# %%
df.loc[1, "ocorrencia_cidade"]
# Out:
# 'BELÉM'

# %%
df.loc[3:5]
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2  ... ocorrencia_hora total_recomendacoes
# 3              39527               39527  ...        17:30:00                   0
# 4              40324               40324  ...        19:25:00                   0
# 5              39807               39807  ...        17:53:00                   0
#
# [3 rows x 9 columns]

# %%
df.loc[[10,40]]
# Out:
#     codigo_ocorrencia  codigo_ocorrencia2  ... ocorrencia_hora total_recomendacoes
# 10              39789               39789  ...        21:30:00                   0
# 40              39158               39158  ...        16:00:00                   0
#
# [2 rows x 9 columns]

# %%
df.loc[:,'ocorrencia_cidade']
# Out:
# 0           RIO DE JANEIRO
# 1                    BELÉM
# 2           RIO DE JANEIRO
# 3       LUCAS DO RIO VERDE
# 4                  PELOTAS
#                ...
# 6109                RECIFE
# 6110           PORTO VELHO
# 6111                 BELÉM
# 6112            DOM AQUINO
# 6113              CAMPINAS
# Name: ocorrencia_cidade, Length: 6114, dtype: object

# %%
df.codigo_ocorrencia.is_unique
# Out:
# True

# %%
df.set_index("codigo_ocorrencia", inplace=True)

# %%
df.head(3)
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2  ... ocorrencia_hora total_recomendacoes
# 0              40211               40211  ...        12:00:00                   0
# 1              40349               40349  ...        11:05:00                   0
# 2                 20                  20  ...              20                  20
#
# [3 rows x 9 columns]

# %%
df.loc[40324]
# Out:
# codigo_ocorrencia2                        40324
# ocorrencia_classificacao              INCIDENTE
# ocorrencia_cidade                       PELOTAS
# ocorrencia_uf                                RS
# ocorrencia_aerodromo                       SBPK
# ocorrencia_dia              2010-01-05 00:00:00
# ocorrencia_hora                        19:25:00
# total_recomendacoes                           0
# Name: 40324, dtype: object

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.loc[1,'ocorrencia_aerodromo'] = 'SBBE'

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2  ... ocorrencia_hora total_recomendacoes
# 0              40211               40211  ...        12:00:00                   0
# 1              40349               40349  ...        11:05:00                   0
# 2              40351               40351  ...        03:00:00                   0
# 3              39527               39527  ...        17:30:00                   0
# 4              40324               40324  ...        19:25:00                   0
#
# [5 rows x 9 columns]

# %%
df['ocorrencia_classificacao_bkp'] = df.ocorrencia_classificacao

# %%
df.loc[df.ocorrencia_uf == 'SP', ['ocorrencia_classificacao']] = 'GRAVE'

# %%
df.loc[df.ocorrencia_uf == 'SP']
# Out:
#       codigo_ocorrencia2  ... ocorrencia_classificacao_bkp
# 11                 40069  ...                     ACIDENTE
# 16                 39809  ...                    INCIDENTE
# 18                 39828  ...                    INCIDENTE
# 26                 39847  ...                    INCIDENTE
# 27                 39768  ...                    INCIDENTE
# ...                  ...  ...                          ...
# 6084               80234  ...                    INCIDENTE
# 6085               80208  ...                    INCIDENTE
# 6104               80238  ...              INCIDENTE GRAVE
# 6108               80244  ...                    INCIDENTE
# 6113               80259  ...                    INCIDENTE
#
# [1464 rows x 10 columns]

# %%
df.loc[2] = 20

# %%
df.loc[:,'total_recomendacoes'] = 10

# %% [markdown]
# Ocorrencia_uf \n
# '***' \n
# Ocorrencia_aerodromo \n
# '###!'
# '####'
# '****'
# '*****' \n
# Ocorrencia_hora
# null

# %%
df.loc[df.ocorrencia_aerodromo == '****', ['ocorrencia_aerodromo']] = pd.NA

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2  ... ocorrencia_hora total_recomendacoes
# 0              40211               40211  ...        12:00:00                   0
# 1              40349               40349  ...        11:05:00                   0
# 2              40351               40351  ...        03:00:00                   0
# 3              39527               39527  ...        17:30:00                   0
# 4              40324               40324  ...        19:25:00                   0
#
# [5 rows x 9 columns]

# %%
df.loc[df.ocorrencia_aerodromo == '*****', ['ocorrencia_aerodromo']] = pd.NA

# %%
df.loc[df.ocorrencia_aerodromo == '###!', ['ocorrencia_aerodromo']] = pd.NA

# %%
df.loc[df.ocorrencia_aerodromo == '####', ['ocorrencia_aerodromo']] = pd.NA

# %%
df.loc[df.ocorrencia_aerodromo == '****']
# Out:
# Empty DataFrame
# Columns: [codigo_ocorrencia, codigo_ocorrencia2, ocorrencia_classificacao, ocorrencia_cidade, ocorrencia_uf, ocorrencia_aerodromo, ocorrencia_dia, ocorrencia_hora, total_recomendacoes]
# Index: []

# %%
df.replace(['**', '****', '*****', '###!', '####', 'NULL'], pd.NA, inplace=True)

# %%
df.fillna(10, inplace=True)

# %%
df.isna().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  2
# ocorrencia_aerodromo        2456
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  2
# ocorrencia_aerodromo        2456
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64

# %%
df.replace([10], pd.NA, inplace=True)

# %%
df.fillna(value={'total_recomendacoes':10}, inplace=True)

# %%
df['total_recomendacoes_bkp'] = df.total_recomendacoes

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2  ... ocorrencia_hora total_recomendacoes
# 0              40211               40211  ...        12:00:00                 0.0
# 1              40349               40349  ...        11:05:00                 0.0
# 2              40351               40351  ...        03:00:00                 0.0
# 3              39527               39527  ...        17:30:00                 0.0
# 4              40324               40324  ...        19:25:00                 0.0
#
# [5 rows x 9 columns]

# %%
df.drop(['total_recomendacoes_bkp'], axis=1, inplace=True)

# %%
df.dropna()
# Out:
#       codigo_ocorrencia  ...  total_recomendacoes
# 1                 40349  ...                  0.0
# 2                 40351  ...                  0.0
# 4                 40324  ...                  0.0
# 6                 40215  ...                  0.0
# 8                 39156  ...                  2.0
# ...                 ...  ...                  ...
# 6108              80244  ...                  0.0
# 6109              80245  ...                  0.0
# 6110              80247  ...                  0.0
# 6111              80251  ...                  0.0
# 6113              80259  ...                  0.0
#
# [3658 rows x 9 columns]

# %%
df
# Out:
#       codigo_ocorrencia  ...  total_recomendacoes
# 0                 40211  ...                  0.0
# 1                 40349  ...                  0.0
# 2                 40351  ...                  0.0
# 3                 39527  ...                  0.0
# 4                 40324  ...                  0.0
# ...                 ...  ...                  ...
# 6109              80245  ...                  0.0
# 6110              80247  ...                  0.0
# 6111              80251  ...                  0.0
# 6112              80257  ...                  0.0
# 6113              80259  ...                  0.0
#
# [6114 rows x 9 columns]

# %%
df.dropna(subset=['ocorrencia_uf'])
# Out:
#       codigo_ocorrencia  ...  total_recomendacoes
# 0                 40211  ...                  0.0
# 1                 40349  ...                  0.0
# 2                 40351  ...                  0.0
# 3                 39527  ...                  0.0
# 4                 40324  ...                  0.0
# ...                 ...  ...                  ...
# 6109              80245  ...                  0.0
# 6110              80247  ...                  0.0
# 6111              80251  ...                  0.0
# 6112              80257  ...                  0.0
# 6113              80259  ...                  0.0
#
# [6112 rows x 9 columns]

# %% [markdown]
# df.drop_duplicates(inplace=True) #para remover duplicatas
